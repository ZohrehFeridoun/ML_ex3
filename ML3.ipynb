# %% [markdown]
# <a href="https://colab.research.google.com/github/ZohrehFeridoun/ML_ex3/blob/main/ML3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# part 1

# %%
import sklearn
import numpy as np
import pandas as pd
import csv
from re import X

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from sklearn import linear_model
from sklearn.preprocessing import Normalizer
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv("/content/Advertising.csv")
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.drop('Unnamed: 0', axis = 1, inplace=True)
display(data)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
X = data[['TV', 'Radio', 'Newspaper']]
Y = data['Sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
transformer = Normalizer().fit(X_train)
normalized_X = transformer.transform( X_test)
print(normalized_X)
# Out:
# [[0.94292952 0.08980281 0.3206546 ]
#  [0.97829147 0.04483357 0.20232585]
#  [0.95541972 0.01474413 0.29488263]
#  [0.97867125 0.06496352 0.19489057]
#  [0.92297292 0.33265734 0.19354609]
#  [0.96649878 0.15793914 0.20232485]
#  [0.99060015 0.1168066  0.07118685]
#  [0.94867684 0.05169654 0.31199315]
#  [0.97642342 0.12546846 0.17565584]
#  [0.97852436 0.1005237  0.1799585 ]
#  [0.96949051 0.03520736 0.24258731]
#  [0.67073563 0.71133278 0.21004616]
#  [0.98687414 0.14116875 0.07842708]
#  [0.99482623 0.09512283 0.03567106]
#  [0.97108021 0.04277556 0.23489034]
#  [0.99624375 0.04200315 0.07572399]
#  [0.59685858 0.52711331 0.60490611]
#  [0.98521944 0.01528619 0.17061358]
#  [0.96368813 0.15534218 0.21719576]
#  [0.84961635 0.19254761 0.49099642]
#  [0.74296404 0.49133097 0.45453088]
#  [0.97604723 0.2170963  0.01417772]
#  [0.99631773 0.00828164 0.08533694]
#  [0.12130755 0.60498252 0.78694385]
#  [0.81545233 0.37776546 0.4385553 ]
#  [0.98965511 0.08305616 0.11698051]
# ...

# %% [markdown]
# part 2

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y2 = model.predict(X_test)

MSE = metrics.mean_squared_error(y_test, y2)

R2 = metrics.r2_score(y_test, y2)

print('MS:', MSE)
print('R:', R2)
# Out:
# MS: 2.508968099961843
# R: 0.914542482043263

# %%
sns.scatterplot(y_test, y2)

plt.title('Linear Regression ')

plt.show()
# Out:
# C:\Users\parsa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
mse = mean_squared_error(y_test , y2)

error=pd.DataFrame({'Target':y_test,'Predicted':y2,'MSE':y_test - y2})

print(error)
# Out:
#      Target  Predicted       MSE
# 85     15.2  15.228197 -0.028197
# 177    11.7  12.162215 -0.462215
# 32      9.6   7.670648  1.929352
# 79     11.0   9.651254  1.348746
# 86     12.0  11.473697  0.526303
# 61     24.2  22.773180  1.426820
# 152    16.6  16.213778  0.386222
# 143    10.4   8.790180  1.609820
# 45     14.9  15.082256 -0.182256
# 116    12.2  11.926852  0.273148
# 110    13.4  14.812861 -1.412861
# 148    10.9  12.078249 -1.178249
# 191     9.9   8.341077  1.558923
# 51     10.7   9.247334  1.452666
# 73     11.0   9.911166  1.088834
# 173    11.7  11.900885 -0.200885
# 1      10.4  12.264875 -1.864875
# 50     11.4  12.642139 -1.242139
# 14     19.0  18.348169  0.651831
# 29     10.5   9.153916  1.346084
# 37     14.7  15.498739 -0.798739
# 128    24.7  21.951477  2.748523
# 178    11.8  15.967952 -4.167952
# 126     6.6  10.534438 -3.934438
# 156    15.3  15.296977  0.003023
# 184    17.6  18.437564 -0.837564
# 157    10.1  10.013392  0.086608
# ...

# %% [markdown]
# part 3

# %%
data = pd.read_csv("/content/Advertising.csv")
data.drop('Unnamed: 0', axis = 1, inplace=True)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
corr = data.corr()

ax = sns.heatmap(corr, annot=True)

# %%
dataset = data.drop(["Newspaper"], axis=1)
m = dataset[["TV", "Radio"]]
d = dataset["Sales"]
print(dataset)
# Out:
#         TV  Radio  Sales
# 0    230.1   37.8   22.1
# 1     44.5   39.3   10.4
# 2     17.2   45.9    9.3
# 3    151.5   41.3   18.5
# 4    180.8   10.8   12.9
# ..     ...    ...    ...
# 195   38.2    3.7    7.6
# 196   94.2    4.9    9.7
# 197  177.0    9.3   12.8
# 198  283.6   42.0   25.5
# 199  232.1    8.6   13.4
#
# [200 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(m,d, test_size=0.2)

# %%
poly_reg = PolynomialFeatures(degree = 2 , include_bias=False)

t_poly = poly_reg.fit_transform(X_train)
print(t_poly)
# Out:
# [[1.826000e+02 4.620000e+01 3.334276e+04 8.436120e+03 2.134440e+03]
#  [2.417000e+02 3.800000e+01 5.841889e+04 9.184600e+03 1.444000e+03]
#  [2.147000e+02 2.400000e+01 4.609609e+04 5.152800e+03 5.760000e+02]
#  [7.530000e+01 2.030000e+01 5.670090e+03 1.528590e+03 4.120900e+02]
#  [2.184000e+02 2.770000e+01 4.769856e+04 6.049680e+03 7.672900e+02]
#  [8.020000e+01 0.000000e+00 6.432040e+03 0.000000e+00 0.000000e+00]
#  [1.725000e+02 1.810000e+01 2.975625e+04 3.122250e+03 3.276100e+02]
#  [1.004000e+02 9.600000e+00 1.008016e+04 9.638400e+02 9.216000e+01]
#  [2.380000e+01 3.510000e+01 5.664400e+02 8.353800e+02 1.232010e+03]
#  [2.613000e+02 4.270000e+01 6.827769e+04 1.115751e+04 1.823290e+03]
#  [1.473000e+02 2.390000e+01 2.169729e+04 3.520470e+03 5.712100e+02]
#  [1.751000e+02 2.250000e+01 3.066001e+04 3.939750e+03 5.062500e+02]
#  [1.205000e+02 2.850000e+01 1.452025e+04 3.434250e+03 8.122500e+02]
#  [6.610000e+01 5.800000e+00 4.369210e+03 3.833800e+02 3.364000e+01]
# ...

# %%
new_train = Normalizer().fit(X_train)
new_test = new_train.transform(X_test)

# %%
model = LinearRegression()
model.fit(new_test, y_test)
# Out:
# LinearRegression()

# %%
y_new = model.predict(new_test)

# %%
error = y_test - y_new

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_new, 'Error': error})
print(df)
# Out:
#      Actual  Predicted      Error
# 150    16.1  14.592606   1.507394
# 79     11.0  14.651774  -3.651774
# 2       9.3   7.551853   1.748147
# 145    10.3  14.449742  -4.149742
# 35     12.8  14.452144  -1.652144
# 158     7.3   6.798272   0.501728
# 36     25.4  14.896292  10.503708
# 68     18.9  14.796455   4.103545
# 137    20.8  14.770016   6.029984
# 191     9.9  14.857716  -4.957716
# 117     9.4  14.436507  -5.036507
# 187    17.3  14.871648   2.428352
# 97     15.5  14.790775   0.709225
# 33     17.4  14.681060   2.718940
# 194    17.3  14.972193   2.327807
# 139    20.7  14.972029   5.727971
# 162    14.9  14.743805   0.156195
# 21     12.5  14.483206  -1.983206
# 5       7.2   4.773098   2.426902
# 80     11.8  14.925196  -3.125196
# 96     11.7  14.467452  -2.767452
# 85     15.2  14.741432   0.458568
# 115    12.6  14.701635  -2.101635
# 29     10.5  14.966447  -4.466447
# 141    19.2  14.924094   4.275906
# 7      13.2  14.894559  -1.694559
# ...

# %% [markdown]
# Part 4

# %%
data = pd.read_csv(r"/content/Advertising.csv")
data.drop('Unnamed: 0', axis = 1, inplace=True)
display(data)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.20)

# %%
REG = SGDRegressor(max_iter=100, verbose=10, learning_rate='adaptive')

tuned_parameters = {'alpha':np.arange(-1,2,0.1)}

estimator = GridSearchCV(REG, param_grid=tuned_parameters, cv=5)

estimator.fit(X_train, y_train)
# Out:
# -- Epoch 1
# Norm: 2907178979177.66, NNZs: 3, Bias: -49851995459.788696, T: 128, Avg. loss: 19958619297489188510593187840.000000
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 1450492056944.85, NNZs: 3, Bias: -137966121120.035217, T: 256, Avg. loss: 24792650571719674351744712704.000000
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 1196062492780.28, NNZs: 3, Bias: -75124595396.882843, T: 384, Avg. loss: 22478595174727087322296221696.000000
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 1335481635745.80, NNZs: 3, Bias: -35124595396.882843, T: 512, Avg. loss: 22128456456835320410556858368.000000
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 1068340293919.06, NNZs: 3, Bias: -69287934951.226669, T: 640, Avg. loss: 22578459651315693555506216960.000000
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 1933248400446.75, NNZs: 3, Bias: -69287934951.226669, T: 768, Avg. loss: 22648849755414731622218465280.000000
# ...

# %%
y_reg = estimator.predict(X_test)
MSE = metrics.mean_squared_error(y_test, y_reg)
print('MS:', MSE)
# Out:
# MS: 2.52725767277449e+21

# %%
m = mean_squared_error(y_test , y_reg)
error=pd.DataFrame({'Target':y_test,'Predicted':y_reg,'MSE':y_test - y_reg})

print(error)
# Out:
#      Target     Predicted           MSE
# 71     12.4  4.309135e+10 -4.309135e+10
# 163    18.0  8.192791e+09 -8.192791e+09
# 101    23.8 -1.092848e+11  1.092848e+11
# 70     18.3 -1.878687e+10  1.878687e+10
# 107     8.7  7.776330e+10 -7.776330e+10
# 108     5.3  1.032608e+11 -1.032608e+11
# 170     8.4  7.855677e+10 -7.855677e+10
# 97     15.5  1.356308e+10 -1.356308e+10
# 187    17.3  2.518276e+09 -2.518276e+09
# 15     22.4 -5.429911e+10  5.429911e+10
# 182     8.7  7.675751e+10 -7.675751e+10
# 14     19.0 -2.961059e+10  2.961059e+10
# 6      11.8  3.973050e+10 -3.973050e+10
# 186    10.3  5.498968e+10 -5.498968e+10
# 118    15.9 -3.305215e+10  3.305215e+10
# 82     11.3  4.560710e+10 -4.560710e+10
# 80     11.8  4.321507e+10 -4.321507e+10
# 13      9.7  7.627284e+10 -7.627284e+10
# 75      8.7 -1.248716e+10  1.248716e+10
# 196     9.7  8.087429e+10 -8.087429e+10
# 83     13.6  8.848429e+09 -8.848429e+09
# 85     15.2 -1.861385e+10  1.861385e+10
# ...
